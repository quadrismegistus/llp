# %% [markdown]
# # ARTFL
#
# Corpus notes for ARTFL.

# %%
import llp

# %%
corpus = llp.load('ARTFL')

# %%
corpus.metadata
# Out:
#                         _llp_                              author corpus  \
# 0     artfl|frantext0513.3524                             Garnier  ARTFL
# 1     artfl|frantext0513.3525                           Henriquez  ARTFL
# 2     artfl|frantext0513.3526              Murat, Henriette-Ju...  ARTFL
# 3     artfl|frantext0513.3527                                 NaN  ARTFL
# 4     artfl|frantext0513.3528                                 NaN  ARTFL
# 5     artfl|frantext0513.3529                                 NaN  ARTFL
# 6     artfl|frantext0513.3530                                 NaN  ARTFL
# 7     artfl|frantext0513.3531                                 NaN  ARTFL
# 8     artfl|frantext0513.3532                                 NaN  ARTFL
# 9     artfl|frantext0513.3533                                 NaN  ARTFL
# 10    artfl|frantext0513.3534                                 NaN  ARTFL
# 11    artfl|frantext0513.3535                                 NaN  ARTFL
# ...
